# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://makelymodaintima.meucatalogodigital.com/'

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}

cookies = {
    'Teste': 'lalala'
}

page = requests.get(url = url, headers = headers, cookies=cookies)

# %%
page.content
# Out:
# b'<!doctype html>\n<html lang="pt-br">\n\n<head>\n\t<!-- Required meta tags -->\n\t<meta charset="utf-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n\t<title>Cat\xc3\xa1logo Digital de Makely Moda \xc3\x8dntima</title>\n\t<meta name=description content="Makely Moda \xc3\x8dntima\r\n\r\nPrazo De Separa\xc3\xa7\xc3\xa3o Dos Pedidos at\xc3\xa9 72 horas ap\xc3\xb3s a confirma\xc3\xa7\xc3\xa3o dos Dados.\r\n\r\nTabela De Cores;\r\n\r\nTONS CLAROS: Branco, Nude, Ros\xc3\xaa, Azul Beb\xc3\xaa, Rosa Claro, Verde Claro, Lil\xc3\xa1s,amarelo.\r\n\r\nTONS ESCUROS: Preto,&nbsp;Vermelho, Azul Marinho,Mescla, Rosa Pink . Bord\xc3\xb4&nbsp;\r\n\r\nMEDIDAS:\r\n\r\nP: 40&nbsp; &nbsp; M: 42&nbsp; &nbsp;G:44&nbsp; &nbsp; GG: 46\r\n\r\nPLUS SIZE: 48&nbsp;XG .&nbsp; 50 XGG.&nbsp;&nbsp;&nbsp;52 EXGG.\r\n" />\n\t<meta name=keywords content="Makely Moda \xc3\x8dntima, makelymodaintima, catalogo online, catalogo digital, catalogo online, cardapio online, catalogo via whatsapp, cardapios online, app de cardapio" />\n\t<meta name=resource-type content=document />\n\t<meta name=revisit-after content=1 />\n\t<meta name=distribution content=Global />\n\t<meta name=rating content=General />\n\t<meta name=author content="Meu Cat\xc3\xa1logo Digital - Cat\xc3\xa1logo Online de Produtos" />\n\t<meta name=language content=pt-br />\n\t<meta name=doc-class content=Completed />\n\t<meta name=doc-rights content=Public />\n\t<meta name=Subject content="Makely Moda \xc3\x8dntima\r\n\r\nPrazo De Separa\xc3\xa7\xc3\xa3o Dos Pedidos at\xc3\xa9 72 horas ap\xc3\xb3s a confirma\xc3\xa7\xc3\xa3o dos Dados.\r\n\r\nTabela De Cores;\r\n\r\nTONS CLAROS: Branco, Nude, Ros\xc3\xaa, Azul Beb\xc3\xaa, Rosa Claro, Verde Claro, Lil\xc3\xa1s,amarelo.\r\n\r\nTONS ESCUROS: Preto,&nbsp;Vermelho, Azul Marinho,Mescla, Rosa Pink . Bord\xc3\xb4&nbsp;\r\n\r\nMEDIDAS:\r\n\r\nP: 40&nbsp; &nbsp; M: 42&nbsp; &nbsp;G:44&nbsp; &nbsp; GG: 46\r\n\r\nPLUS SIZE: 48&nbsp;XG .&nbsp; 50 XGG.&nbsp;&nbsp;&nbsp;52 EXGG.\r\n" />\n\t<meta name=audience content=all />\n\t<meta name=robots content="index,follow" />\n\t<meta name=googlebot content=all />\n\t<meta name=copyright content="Meu Cat\xc3\xa1logo Digital - Cat\xc3\xa1logo Online de Produtos" />\n\t<meta name=url content="http://makelymodaintima.meucatalogodigital.com/" />\n\t<meta name=audience content=all />\n\t<meta property="og:url" content="https://makelymodaintima.meucatalogodigital.com/" />\n\t<meta property="og:type" content="website" />\n\t<meta property="og:title" content="Cat\xc3\xa1logo Digital de Makely Moda \xc3\x8dntima" />\n\t<meta property="og:description" content="Makely Moda \xc3\x8dntima\r\n\r\nPrazo De Separa\xc3\xa7\xc3\xa3o Dos Pedidos at\xc3\xa9 72 horas ap\xc3\xb3s a confirma\xc3\xa7\xc3\xa3o dos Dados.\r\n\r\nTabela De Cores;\r\n\r\nTONS CLAROS: Branco, Nude, Ros\xc3\xaa, Azul Beb\xc3\xaa, Rosa Claro, Verde Claro, Lil\xc3\xa1s,amarelo.\r\n\r\nTONS ESCUROS: Preto,&nbsp;Vermelho, Azul Marinho,Mescla, Rosa Pink . Bord\xc3\xb4&nbsp;\r\n\r\nMEDIDAS:\r\n\r\nP: 40&nbsp; &nbsp; M: 42&nbsp; &nbsp;G:44&nbsp; &nbsp; GG: 46\r\n\r\nPLUS SIZE: 48&nbsp;XG .&nbsp; 50 XGG.&nbsp;&nbsp;&nbsp;52 EXGG.\r\n" />\n\t\t<meta property="og:image" content="https://cdn.meucatalogodigital.com/makelymodaintima/logo-1.png" />\n\n\t<link rel="shortcut icon" href="/favicon.ico">\n\t<style>\n\t\t:root {\n\t\t\t--alternative-color: #EC2889;\n\t\t}\n\n\t\t.btn-color {\n\t\t\tbackground-color: #1CB729 !important;\n\t\t}\n\n\t\t.btn-color2 {\n\t\t\tborder-color: #1CB729 !important;\n\t\t\tcolor: #1CB729 !important;\n\t\t}\n\n\t\t.btn-color2 svg {\n\t\t\tfill: #1CB729 !important;\n\t\t}\n\t</style>\n\t<link href="https://fonts.googleapis.com/css?family=Dosis:500|Poppins:400,600&display=swap" rel="stylesheet">\n\t<link href="/css/estilos.css?ok=7" rel="stylesheet">\n\t<link rel="stylesheet" href="/owl-carousel/assets/owl.carousel.css">\n\t<link rel="stylesheet" href="/owl-carousel/assets/owl.theme.default.css?ok=2">\n\t<l ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
itemsLoja = soup.findAll(attrs = {'class': 'box-produto'})

# %%
itemsLoja[0].value
